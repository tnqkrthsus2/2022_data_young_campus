# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.randn(100))

# %%
x = np.linspace(0, np.pi*2, 201)
plt.plot(x, np.sin(x))
plt.show()

# %%
randn_cumsum = np.random.randn(1000).cumsum()

# %%
fig, ax = plt.subplots()
ax.set_title("제목")
ax.set_xlabel('x축 이름')
ax.set_ylabel('y축 이름')
ax.set_xticklabels(['one','two','three','four','five','six'])
ax.annotate('point',xy=(250,randn_cumsum[250]+0.5),
           xytext=(250,randn_cumsum[250]+10),
           arrowprops=dict(facecolor='black',headwidth=4,width=2,headlength=4),
           horizontalalignment='left',
           verticalalignment='top')
ax.plot(randn_cumsum)
plt.show()

# %%
np_randn = np.random.randn(50)

# %%
fig, axes = plt.subplots(2,3)
axes[0,0].hist(np_randn, bin)

# %%
fig, axes =

# %%
n = 100
random_list = np.random.rand(1,n)
random_list = random_list.reshape(2,-1)
ax = random_list.scatte
